# %% [markdown]
# ###**Preprocessing for olympic_athletes**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re

# %%
df_athletes = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/olympic_athletes.csv", sep = ",")

# %%
#Dropped columns because of too many NULL values and unreadable
df_athletes = df_athletes.drop(columns =  ["bio", "athlete_url", "athlete_medals"])
df_athletes
# Out:
#             athlete_full_name  games_participations        first_game  \
# 0      Cooper WOODS-TOPALOVIC                     1      Beijing 2022
# 1              Felix ELOFSSON                     2  PyeongChang 2018
# 2               Dylan WALCZYK                     1      Beijing 2022
# 3               Olli PENTTALA                     1      Beijing 2022
# 4            Dmitriy REIKHERD                     1      Beijing 2022
# ...                       ...                   ...               ...
# 75899          Douglas WEIGLE                     1    Innsbruck 1976
# 75900        Stefania BERTELE                     1    Innsbruck 1976
# 75901          Walter CECCONI                     1    Innsbruck 1976
# 75902            Susan KELLEY                     1    Innsbruck 1976
# 75903        Andrew STROUKOFF                     1    Innsbruck 1976
#
#        athlete_year_birth
# 0                  2000.0
# 1                  1995.0
# 2                  1993.0
# ...

# %%
#Drop NULL values
total_nan_count = df_athletes.isna().sum().sum()
total_nan_count #Tehy're just 2478 over 75904 rows so we can drop them withouth affecting much our queries
# Out:
# 2478

# %%
df_athletes = df_athletes.dropna()
df_athletes
# Out:
#             athlete_full_name  games_participations        first_game  \
# 0      Cooper WOODS-TOPALOVIC                     1      Beijing 2022
# 1              Felix ELOFSSON                     2  PyeongChang 2018
# 2               Dylan WALCZYK                     1      Beijing 2022
# 3               Olli PENTTALA                     1      Beijing 2022
# 4            Dmitriy REIKHERD                     1      Beijing 2022
# ...                       ...                   ...               ...
# 75899          Douglas WEIGLE                     1    Innsbruck 1976
# 75900        Stefania BERTELE                     1    Innsbruck 1976
# 75901          Walter CECCONI                     1    Innsbruck 1976
# 75902            Susan KELLEY                     1    Innsbruck 1976
# 75903        Andrew STROUKOFF                     1    Innsbruck 1976
#
#        athlete_year_birth
# 0                  2000.0
# 1                  1995.0
# 2                  1993.0
# ...

# %%
# Get the duplicate rows
duplicate_rows = df_athletes[df_athletes['athlete_full_name'].duplicated(keep=False)]
duplicate_rows
# Out:
#            athlete_full_name  games_participations        first_game  \
# 150    Chloe DUFOUR-LAPOINTE                     4    Vancouver 2010
# 263               Yujin JANG                     1      Beijing 2022
# 277        Sofia PROSVIRNOVA                     3        Sochi 2014
# 320           Pavel SITNIKOV                     2  PyeongChang 2018
# 340             Tianyi ZHANG                     1      Beijing 2022
# ...                      ...                   ...               ...
# 75500       Gunnar JOHANSSON                     1       London 1948
# 75530             Jiri PECKA                     1       London 1948
# 75584          Miklos NEMETH                     1       Berlin 1936
# 75767            Karl KÖTHER                     1    Amsterdam 1928
# 75889           David PORTER                     1    Innsbruck 1976
#
#        athlete_year_birth
# 150                1991.0
# 263                2001.0
# 277                1997.0
# 320                1998.0
# ...

# %%
#Drop all rows with duplicate 'athlete_full_name'
df_athletes = df_athletes.drop_duplicates(subset='athlete_full_name', keep=False)

# %%
df_athletes
# Out:
#             athlete_full_name  games_participations        first_game  \
# 0      Cooper WOODS-TOPALOVIC                     1      Beijing 2022
# 1              Felix ELOFSSON                     2  PyeongChang 2018
# 2               Dylan WALCZYK                     1      Beijing 2022
# 3               Olli PENTTALA                     1      Beijing 2022
# 4            Dmitriy REIKHERD                     1      Beijing 2022
# ...                       ...                   ...               ...
# 75899          Douglas WEIGLE                     1    Innsbruck 1976
# 75900        Stefania BERTELE                     1    Innsbruck 1976
# 75901          Walter CECCONI                     1    Innsbruck 1976
# 75902            Susan KELLEY                     1    Innsbruck 1976
# 75903        Andrew STROUKOFF                     1    Innsbruck 1976
#
#        athlete_year_birth
# 0                  2000.0
# 1                  1995.0
# 2                  1993.0
# ...

# %%
df_athletes.to_csv('olympic_athletes_new.csv', index = False)

# %% [markdown]
# ###**Preprocessing for olympic_medals**

# %%
df_medals = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/olympic_medals.csv", sep = ",")

# %%
#Dropped columns because of duplicated information and too many NULL values
df_medals = df_medals.drop(columns =  ["participant_title", "athlete_url", "country_code", "country_3_letter_code"])
df_medals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type        athlete_full_name  \
# ...

# %%
df_medals.dropna(subset=['athlete_full_name'], inplace=True)

# %%
df_medals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type        athlete_full_name  \
# ...

# %%
df_medals.to_csv('olympic_medals_new.csv', index = False)

# %% [markdown]
# ###**Preprocessing for olympic_hosts**

# %%
df_hosts = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/olympic_hosts.csv", sep = ",")

# %%
#Proper datetime to be readable for MySQL
df_hosts['game_end_date'] = pd.to_datetime(df_hosts['game_end_date']).dt.strftime('%Y-%m-%d %H:%M:%S')
df_hosts['game_start_date'] = pd.to_datetime(df_hosts['game_start_date']).dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df_hosts.to_csv('olympic_hosts_new.csv', index = False)

# %% [markdown]
# ###**Preprocessing for olympic_results**

# %%
df_results = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/olympic_results.csv", sep = ",")

# %%
#Dropped columns because of too many NULL values, unreadable and duplicate information
df_results = df_results.drop(columns =  ["rank_equal", "athlete_url", "country_code", "country_3_letter_code", "value_type", "value_unit"])
df_results
# Out:
#            discipline_title  \
# 0                   Curling
# 1                   Curling
# 2                   Curling
# 3                   Curling
# 4                   Curling
# ...                     ...
# 162799          Ski Jumping
# 162800          Ski Jumping
# 162801          Ski Jumping
# 162802          Ski Jumping
# 162803  Gymnastics Artistic
#
#                                               event_title      slug_game  \
# 0                                           Mixed Doubles   beijing-2022
# 1                                           Mixed Doubles   beijing-2022
# 2                                           Mixed Doubles   beijing-2022
# 3                                           Mixed Doubles   beijing-2022
# 4                                           Mixed Doubles   beijing-2022
# ...                                                   ...            ...
# 162799                         Normal Hill Individual men  chamonix-1924
# ...

# %%
#Delete rows from a DataFrame in Python where both athlete_full_name and athletes columns do not have values
df_results.dropna(subset=['athlete_full_name', 'athletes'], how='all', inplace=True)

# %%
#Because the format fo the values was "[('Stefania CONSTANTINI', 'https://olympics.co..." and we were interested only in atheltes name we extracted them from "athletes"
#using Regex patterns
pattern = r"'([^',]+)'(?=, 'https)"
df_results['athletes']= df_results['athletes'].apply(lambda x: re.findall(pattern, x) if pd.notnull(x) and isinstance(x, str) else np.nan)

# %%
df_results
# Out:
#        discipline_title                 event_title      slug_game  \
# 0               Curling               Mixed Doubles   beijing-2022
# 1               Curling               Mixed Doubles   beijing-2022
# 2               Curling               Mixed Doubles   beijing-2022
# 3               Curling               Mixed Doubles   beijing-2022
# 4               Curling               Mixed Doubles   beijing-2022
# ...                 ...                         ...            ...
# 162798      Ski Jumping  Normal Hill Individual men  chamonix-1924
# 162799      Ski Jumping  Normal Hill Individual men  chamonix-1924
# 162800      Ski Jumping  Normal Hill Individual men  chamonix-1924
# 162801      Ski Jumping  Normal Hill Individual men  chamonix-1924
# 162802      Ski Jumping  Normal Hill Individual men  chamonix-1924
#
#        participant_type medal_type                                athletes  \
# 0              GameTeam       GOLD    [Stefania CONSTANTINI, Amos MOSANER]
# ...

# %%
df_results.to_csv('olympic_results_new.csv', index = False)

# %% [markdown]
# ---------------------------------------------------------------------
# ###**Create index for the foreign key between medals and hosts, and between athletes and hosts**

# %% [markdown]
# ```
# hosts and medals
# ```

# %%
df_medals = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/new csv/olympic_medals_new.csv", sep = ";")
df_hosts = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/new csv/olympic_hosts_new.csv", sep = ";")
df_athletes = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/new csv/olympic_athletes_new.csv", sep = ";")

# %%
#hosts - medals
merged_df = df_medals.merge(df_hosts, left_on='slug_game', right_on='game_slug', how='left')
merged_df.drop(["game_slug","game_end_date","game_start_date","game_location","game_name","game_season","game_year"], axis=1, inplace=True)

# %% [markdown]
# ```
# Athlete and medals
# ```

# %%
#athletes - medals
merged_df = merged_df.merge(df_athletes, left_on='athlete_full_name', right_on='athlete_full_name', how='left')
merged_df.drop(["games_participations",	"first_game",	"athlete_year_birth", "Unnamed: 5"], axis=1, inplace=True)

# %%
merged_df = merged_df.dropna(subset=['ID_athletes']) #delete rows that have ID_athletes = NaN

merged_df['ID_athletes'] = merged_df['ID_athletes'].astype(int)
# Out:
# <ipython-input-17-cc8e73c135fc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['ID_athletes'] = merged_df['ID_athletes'].astype(int)

# %%
merged_df
# Out:
#        ID_medals discipline_title     slug_game  \
# 0              1          Curling  beijing-2022
# 1              2          Curling  beijing-2022
# 2              3          Curling  beijing-2022
# 3              4          Curling  beijing-2022
# 4              5          Curling  beijing-2022
# ...          ...              ...           ...
# 18064      18065        Wrestling   athens-1896
# 18065      18066        Wrestling   athens-1896
# 18068      18069    Weightlifting   athens-1896
# 18070      18071    Weightlifting   athens-1896
# 18072      18073    Weightlifting   athens-1896
#
#                             event_title event_gender medal_type  \
# 0                         Mixed Doubles        Mixed       GOLD
# 1                         Mixed Doubles        Mixed       GOLD
# 2                         Mixed Doubles        Mixed     SILVER
# 3                         Mixed Doubles        Mixed     SILVER
# ...

# %%
merged_df.to_csv('olympic_medals_new.csv', index = False)

# %% [markdown]
# ###**Create index for the foreign key between results and hosts**

# %%
df_hosts = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/new csv/olympic_hosts_new.csv", sep = ";")
df_results = pd.read_csv("/content/drive/MyDrive/DATA SCIENCE 23 24/2nd semester/Data managment/1st. Project/new csv/olympic_results_new.csv", sep = ";")

# %%
#results - hosts
merged_df = df_results.merge(df_hosts, left_on='slug_game', right_on='game_slug', how='left')
merged_df.drop(["game_slug","game_end_date","game_start_date","game_location","game_name","game_season","game_year"], axis=1, inplace=True)

# %%
merged_df
# Out:
#         ID_results discipline_title                 event_title  \
# 0                1          Curling               Mixed Doubles
# 1                2          Curling               Mixed Doubles
# 2                3          Curling               Mixed Doubles
# 3                4          Curling               Mixed Doubles
# 4                5          Curling               Mixed Doubles
# ...            ...              ...                         ...
# 149617      149618      Ski Jumping  Normal Hill Individual men
# 149618      149619      Ski Jumping  Normal Hill Individual men
# 149619      149620      Ski Jumping  Normal Hill Individual men
# 149620      149621      Ski Jumping  Normal Hill Individual men
# 149621      149622      Ski Jumping  Normal Hill Individual men
#
#             slug_game participant_type medal_type  \
# 0        beijing-2022         GameTeam       GOLD
# 1        beijing-2022         GameTeam     SILVER
# ...

# %%
merged_df.to_csv('olympic_results_new.csv', index = False)
